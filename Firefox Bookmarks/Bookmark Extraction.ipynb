# %%
import pandas as pd

# %%
df = pd.read_excel('DG_Bookmarks.xlsx')

# %%
for i in df['url']:
    print(i)
# Out:
# https://www.eramet-comilog.com/Le-Manganese-12.html
# https://www.orano.group/fr/expertise-sur-tout-le-site/tour-des-implantations/mines-uranium/niger/exploitation-responsable
# https://www.cameco.com/businesses
# http://www.priargunsky.armz.ru/en/
# https://www.manganese.org/membership/#
# https://www.rossing.com/
# http://www.swakopuranium.com/
# https://www.world-nuclear.org/information-library/country-profiles/countries-a-f/appendices/australia-s-uranium-mines.aspx
# https://books.google.co.ma/books?id=TlbJrzRqNxEC&pg=PA28&lpg=PA28&dq=sintering+feed+with+manganese+for+steel+plant+australia&source=bl&ots=G74TKXSdQa&sig=ACfU3U3mF133O01UC_g8D1pLIajGXwwa3g&hl=fr&sa=X&authuser=1#v=onepage&q=sintering%20feed%20with%20manganese%20for%20steel%20plant%20australia&f=false
# http://www.scielo.org.za/scielo.php?script=sci_arttext&pid=S2225-62532016001100006
# http://eickhoff.co.za/continous-miner/continuous-miner.asp
# ...

# %%
import webbrowser

url = 'https://pythonexamples.org'
webbrowser.register('firefox',
	None,
	webbrowser.BackgroundBrowser("C://Program Files (x86)//Mozilla Firefox//firefox.exe"))
webbrowser.get('firefox').open(url) # C:\Program Files (x86)\Mozilla Firefox
# Out:
# True

# %%
bk = df['url']

# %%
bk
# Out:
# 0      https://www.eramet-comilog.com/Le-Manganese-12...
# 1      https://www.orano.group/fr/expertise-sur-tout-...
# 2                      https://www.cameco.com/businesses
# 3                     http://www.priargunsky.armz.ru/en/
# 4                 https://www.manganese.org/membership/#
#                              ...
# 233               http://www.brockmetals.sk/contact.html
# 234                      https://www.reazn.com/about-us/
# 235                    https://www.zinc.org/iza-members/
# 236    https://www.metso.com/contacts/?industry=4821&...
# 237    https://depotbilan.justice.gov.ma/Account/Logi...
# Name: url, Length: 238, dtype: object

# %%
for i in bk.iloc[230:]:
    print(i)
    webbrowser.get('firefox').open(i) # C:\Program Files (x86)\Mozilla Firefox
# Out:
# https://www.galfan.com/manufactures.html
# http://en.zinc.ru/about/contacts/
# https://www.heneken.com/en/contact
# http://www.brockmetals.sk/contact.html
# https://www.reazn.com/about-us/
# https://www.zinc.org/iza-members/
# https://www.metso.com/contacts/?industry=4821&tags=20311,687,38,3771,1031,1000,999,687,789
# https://depotbilan.justice.gov.ma/Account/Login?returnUrl=%2F%3FAspxAutoDetectCookieSupport%3D1
